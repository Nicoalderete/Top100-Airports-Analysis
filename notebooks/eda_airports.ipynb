# %%
# Importar librería 
import pandas as pd

# Carga del dataset 
file_path = "/Users/nicolasalderete/Documents/Proyectos/Top-100-Airports-Analysis/data/Top 100 Bussiest Airports in the World - Sheet2.csv"  
df = pd.read_csv("/Users/nicolasalderete/Documents/Proyectos/Top-100-Airports-Analysis/data/Top 100 Bussiest Airports in the World - Sheet2.csv")

# Inspeccionar la estructura del dataset
print("📌 Dimensiones del dataset:", df.shape)  # Número de filas y columnas
print("\n📌 Primeras filas del dataset:")
display(df.head())  # Primeras 5 filas

print("\n📌 Información general del dataset:")
df.info()  # Información sobre tipos de datos y valores nulos

print("\n📌 Estadísticas descriptivas:")
display(df.describe())  # Estadísticas de columnas numéricas

print("\n📌 Valores nulos por columna:")
print(df.isnull().sum())  # Recuento de valores nulos en cada columna
# Out:
# 📌 Dimensiones del dataset: (100, 6)
#
# 📌 Primeras filas del dataset:
#    Rank                                           Airport Code     Location  \
# 0     1  Hartsfield–Jackson Atlanta International Airport  ATL      Atlanta
# 1     2             Beijing Capital International Airport  PEK      Beijing
# 2     3                       Dubai International Airport  DXB        Dubai
# 3     4                 Los Angeles International Airport  LAX  Los Angeles
# 4     5                      O'Hare International Airport  ORD      Chicago
#
#                 Country   Passengers
# 0         United States  103,902,992
# 1                 China   95,786,442
# 2  United Arab Emirates   88,242,099
# 3         United States   84,557,968
# 4         United States   79,828,183
# 📌 Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ...
